# %% [markdown]
# # 記述統計

# %%
import pandas_datareader.data as pdr
import datetime
start = datetime.datetime(2009,9,1)
end = datetime.datetime(2019,8,30)
JPUS = pdr.DataReader('DEXJPUS', 'fred', start, end)
JPUS.columns=['p'] #項目名をpに変更
JPUSr = JPUS['p'].pct_change().dropna() #収益率

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig, ax=plt.subplots(2,1,figsize=(8,8))
ax[0].plot(JPUS)
ax[1].plot(JPUSr)

# %%
JPUSr.hist(bins=50)

# %%
from scipy.stats import norm
import numpy as np
x=np.linspace(float(JPUSr.min()),float(JPUSr.max()),100)
pdf=norm.pdf(x,JPUSr.mean(),JPUSr.std())

JPUSr.hist(bins=100, density=True, color='lightgray')
plt.plot(x,pdf)

# %%
print("count: %d"%JPUSr.count())
print("mean: %2.5f"%JPUSr.mean())
print("std: %2.5f"%JPUSr.std())
print("skew: %2.5f"%JPUSr.skew())
print("kurt: %2.5f"%JPUSr.kurt())
# Out:
# count: 2608
# mean: 0.00007
# std: 0.00577
# skew: 0.18129
# kurt: 3.95834

# %%
print("mean %2.5f std %2.5f skew %2.5f kurt %2.5f"%(JPUSr.mean(), JPUSr.std(), JPUSr.skew(), JPUSr.kurt()))
# Out:
# mean 0.00007 std 0.00577 skew 0.18129 kurt 3.95834

# %%
JPUSr.mean()*250
# Out:
# 0.01687252059032012

# %%
JPUSr.std()*np.sqrt(250)
# Out:
# 0.09117222228013298

# %%
JPUSr.describe()
# Out:
# count    2608.000000
# mean        0.000067
# std         0.005766
# min        -0.034372
# 25%        -0.002808
# 50%         0.000000
# 75%         0.003002
# max         0.033993
# Name: p, dtype: float64

# %%
JPUS.skew()
# Out:
# p   -0.271636
# dtype: float64

# %%
JPUS.kurt()
# Out:
# p   -1.200917
# dtype: float64

# %%
print(JPUSr.describe())
print(JPUS.skew())
# Out:
# count    2608.000000
# mean        0.000067
# std         0.005766
# min        -0.034372
# 25%        -0.002808
# 50%         0.000000
# 75%         0.003002
# max         0.033993
# Name: p, dtype: float64
# p   -0.271636
# dtype: float64

# %% [markdown]
# **おまけ 原系列**

# %%
JPUS.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x117b0e3c8>]],
#       dtype=object)

# %%
JPUS.describe()
# Out:
#                  p
# count  2503.000000
# mean    100.566948
# std      14.113187
# min      75.720000
# 25%      87.585000
# 50%     102.800000
# 75%     111.620000
# max     125.580000
